# %% [markdown]
# # ------------------------------
# # JEPPESEN PROJECT
# # ------------------------------
# ### Parse data from NAVDATA_POINTS, NAVDATA_SEGMENTS and the .srad-file from Jeppesen

# %%
import pandas as pd
import numpy as np
from graph import Graph

mapping = {"1": "W",
           "2": "V",
           "3": "N",
           "4": "D",
           "5": "A",
           "6": "R"}

#Read all segments from file
segmentSource = open("../data/NAVDATA_SEGMENTS", 'r')
segmentlist = segmentSource.readlines()
segmentSource.close()

#Create list of segment tuples, becoming edges in our graph
segments = []
for line in segmentlist:
    if line[15]=="Z" or line[29]=="Z":
        seg = (line[9:14].strip(), line[23:28].strip())
        seg = (seg[0]+" "+mapping[line[21]], seg[1]+" "+mapping[line[35]])
        segments.append(seg)

#create the graph
g=Graph(segments, directed=True)
#print(g._graph)
#print(g._graph['IDUMA'])

#Read in allowed paths from .srad file
sradfile = open("../data/_CHINA_MANDATE_OVERFLIGHT.srad", 'r')
srad = sradfile.readlines()
sradfile.close()

#Find the index of all mandate routes sequences in the code
index = [];
for i,line in enumerate(srad):
    if "Seq" in line:
        index.append(i)

#Get every allowed route
allowed_routes = []
for i,ind in enumerate(index):
    allowed_routes.append([])
    if ind != index[-1]:
        for line in srad[ind+1:index[i+1]]:
            node = line.split()
            seg = (node[9]+" "+node[8][0], node[13]+" "+node[12][0])
            allowed_routes[i].append(seg)
    else:
        for line in srad[ind+1:len(srad)]:
            node = line.split()
            seg = (node[9]+" "+node[8][0], node[13]+" "+node[12][0])
            allowed_routes[i].append(seg)

print(allowed_routes)
# Out:
# [[('INTIK W', 'ASURI W'), ('ASURI W', 'PADSA W'), ('PADSA W', 'HET V'), ('HET V', 'DOTOS W'), ('DOTOS W', 'ISBAM W'), ('ISBAM W', 'ATPOK W'), ('ATPOK W', 'TODAM W'), ('TODAM W', 'EKETA W'), ('EKETA W', 'TYN V'), ('TYN V', 'XIVEP W'), ('XIVEP W', 'ANPIG W'), ('ANPIG W', 'EGEBI W'), ('EGEBI W', 'SQ N'), ('SQ N', 'PADNO W'), ('PADNO W', 'TAMIX W'), ('TAMIX W', 'NOPIN W'), ('NOPIN W', 'DUBAG W'), ('DUBAG W', 'CGO V'), ('CGO V', 'KAMDA W'), ('KAMDA W', 'OBLIK W'), ('OBLIK W', 'ESDOS W'), ('ESDOS W', 'HOK V'), ('HOK V', 'LKO V'), ('LKO V', 'DAPRO W'), ('DAPRO W', 'AKUBA W'), ('AKUBA W', 'LUMKO W'), ('LUMKO W', 'PAVTU W'), ('PAVTU W', 'LIG V'), ('LIG V', 'NIVEM W'), ('NIVEM W', 'BEMAG W'), ('BEMAG W', 'NNX V'), ('NNX V', 'WYN V'), ('WYN V', 'SANIP W'), ('SANIP W', 'NOMAR W'), ('NOMAR W', 'UBLIM W'), ('UBLIM W', 'NLG V'), ('NLG V', 'TAMOT W')], [('SADLI W', 'LAMEN W'), ('LAMEN W', 'AKARA W'), ('AKARA W', 'DUMET W'), ('DUMET W', 'IPRAG W'), ('IPRAG W', 'PUD V'), ('PUD V', 'PK N'), ('PK N', 'EKIMU W'), ('EKIMU W', 'SASAN W'), ('SASAN W', 'ESBAG W'), ('ESBAG W', 'LUPVI W'), ('LUPVI W', 'OLRIS W'), ('OLRIS W', 'UPLEL W'), ('UPLEL W', 'MADUK W'), ('MADUK W', 'HFE V'), ('HFE V', 'MAGLI W'), ('MAGLI W', 'PEDNU W'), ('PEDNU W', 'BIPIM W'), ('BIPIM W', 'FYG V'), ('FYG V', 'ZHO V'), ('ZHO V', 'CGO V'), ('CGO V', 'DUBAG W'), ('DUBAG W', 'NOPIN W'), ('NOPIN W', 'TAMIX W'), ('TAMIX W', 'PADNO W'), ('PADNO W', 'SQ N'), ('SQ N', 'EGEBI W'), ('EGEBI W', 'ANPIG W'), ('ANPIG W', 'XIVEP W'), ('XIVEP W', 'TYN V'), ('TYN V', 'EKETA W'), ('EKETA W', 'TODAM W'), ('TODAM W', 'ATPOK W'), ('ATPOK W', 'ISBAM W'), ('ISBAM W', 'DOTOS W'), ('DOTOS W', 'HET V'), ('HET V', 'PADSA W'), ('PADSA W', 'ASURI W'), ('ASURI W', 'INTIK W')], [('LINSO W', 'GMA V'), ('GMA V', 'MAKUL W'), ('MAKUL W', 'GULOT W'), ('GULOT W', 'SGM V'), ('SGM V', 'XFA V'), ('XFA V', 'XISLI W'), ('XISLI W', 'LPS V'), ('LPS V', 'QNX V'), ('QNX V', 'BIPIP W'), ('BIPIP W', 'AGTIS W'), ('AGTIS W', 'MEMAG W'), ('MEMAG W', 'EKADI W'), ('EKADI W', 'TAXOR W'), ('TAXOR W', 'EPGAL W'), ('EPGAL W', 'HUY V'), ('HUY V', 'NOMUK W'), ('NOMUK W', 'LIN V'), ('LIN V', 'GUGAM W'), ('GUGAM W', 'WHA V'), ('WHA V', 'SAGUD W'), ('SAGUD W', 'BIVIP W'), ('BIVIP W', 'MIDOX W'), ('MIDOX W', 'UXALO W'), ('UXALO W', 'HFE V'), ('HFE V', 'MADUK W'), ('MADUK W', 'UPLEL W'), ('UPLEL W', 'OLRIS W'), ('OLRIS W', 'LUPVI W'), ('LUPVI W', 'ESBAG W'), ('ESBAG W', 'SASAN W'), ('SASAN W', 'EKIMU W'), ('EKIMU W', 'PK N'), ('PK N', 'JTN V'), ('JTN V', 'NINAS W'), ('NINAS W', 'LASAN W'), ('LASAN W', 'BONGI W'), ('BONGI W', 'BOLEX W'), ('BOLEX W', 'TONIX W'), ('TONIX W', 'LAMEN W'), ('LAMEN W', 'SADLI W')], [('INTIK W', 'ASURI W'), ('ASURI W', 'PADSA W'), ('PADSA W', 'HET V'), ('HET V', 'DOTOS W'), ('DOTOS W', 'ISBAM W'), ('ISBAM W', 'ATPOK W'), ('ATPOK W', 'TODAM W'), ('TODAM W', 'EKETA W'), ('EKETA W', 'TYN V'), ('TYN V', 'XIVEP W'), ('XIVEP W', 'ANPIG W'), ('ANPIG W', 'EGEBI W'), ('EGEBI W', 'SQ N'), ('SQ N', 'PADNO W'), ('PADNO W', 'TAMIX W'), ('TAMIX W', 'NOPIN W'), ('NOPIN W', 'DUBAG W'), ('DUBAG W', 'CGO V'), ('CGO V', 'KAMDA W'), ('KAMDA W', 'FYG V'), ('FYG V', 'BIPIM W'), ('BIPIM W', 'PEDNU W'), ('PEDNU W', 'MAGLI W'), ('MAGLI W', 'HFE V'), ('HFE V', 'MADUK W'), ('MADUK W', 'UPLEL W'), ('UPLEL W', 'OLRIS W'), ('OLRIS W', 'LUPVI W'), ('LUPVI W', 'ESBAG W'), ('ESBAG W', 'SASAN W'), ('SASAN W', 'EKIMU W'), ('EKIMU W', 'PK N'), ('PK N', 'JTN V'), ('JTN V', 'NINAS W'), ('NINAS W', 'LASAN W'), ('LASAN W', 'BONGI W'), ('BONGI W', 'BOLEX W'), ('BOLEX W', 'TONIX W'), ('TONIX W', 'LAMEN W'), ('LAMEN W', 'SADLI W')], [('MORIT W', 'GOBIN W'), ('GOBIN W', 'YBL V'), ('YBL V', 'AKMAT W'), ('AKMAT W', 'JTA V'), ('JTA V', 'SUNUV W'), ('SUNUV W', 'XIXAN W'), ('XIXAN W', 'BESMI W'), ('BESMI W', 'ELPAN W'), ('ELPAN W', 'OMBON W'), ('OMBON W', 'DOREX W'), ('DOREX W', 'JTG V'), ('JTG V', 'WFX V'), ('WFX V', 'ZYG V'), ('ZYG V', 'YBN V'), ('YBN V', 'DONLA W'), ('DONLA W', 'RELUT W'), ('RELUT W', 'HX N'), ('HX N', 'MEBNA W'), ('MEBNA W', 'XFA V'), ('XFA V',  ...
